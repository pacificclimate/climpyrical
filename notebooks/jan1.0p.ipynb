# %%
import sys
sys.path.append('../modules')

from operators import *
from preprocessing import *
from eof import *
from gridding import *
from mapper import *
from scipy.stats import linregress

import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.feature
import seaborn as sns
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Jan Temp Quantiles
# ---
# Load data and interpolate the design value field

# %%
PATH = '/storage/data/projects/nrc/CanRCM4_large_ensemble/design_values/tas/jan1.0p/tas_CanRCM4-LE_ens35_1951-2016_1hr_jan1.0p.nc'
mask_path = '/home/nannau/Desktop/climpyrical/data/mask.nc'
dv = 'tas'

interp_dict = get_interpolation(mask_path, PATH, dv)
master_idx = interp_dict['idx']
iens = (interp_dict['iens'][:, master_idx])

# %% [markdown]
# Plot distribution.

# %%
plt.figure(figsize=(10, 6))
sns.distplot(iens[0, ...])
plt.title('KDE Distribution of {} Values'.format(dv))
# Out:
# Text(0.5, 1.0, 'KDE Distribution of tas Values')

# %% [markdown]
# Perform singular value decomposition

# %%
u, s, vT = np.linalg.svd(iens, full_matrices=False)
del u

# %% [markdown]
# Calculate explained variance and plot

# %%
explained_variance_ratio = [s[i]/np.sum(s) for i in range(s.shape[0])]
cumulative_variance = np.cumsum(explained_variance_ratio)
component = range(s.shape[0])

plt.figure(figsize=(10, 6))
plt.plot(component, explained_variance_ratio)
plt.xlabel('Component')
plt.ylabel('Explained Variance Ratio')
# Out:
# Text(0, 0.5, 'Explained Variance Ratio')

# %% [markdown]
# Load the quantile station data

# %%
df = pd.read_csv('/home/nannau/Desktop/climpyrical/data/jan_1st_percentile_1991_2016', index_col=None)
# df = df[df['completeness'] > 0.8]

# %%
ndf = match_coords(df, interp_dict, 'quantile')
print("There are ", ndf.shape, "real station observations to fit.")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-8b52db61cb62> in <module>
# ----> 1 ndf = match_coords(df, interp_dict, 'quantile')
#       2 print("There are ", ndf.shape, "real station observations to fit.")
#
# ~/Desktop/climpyrical/modules/gridding.py in match_coords(df, interp_dict, dv_obs_name)
#     155
#     156     # get the nearest grids
# --> 157     df['nearest_grid'] = dist_index(obs_coords, ens_coords)
#     158     df['obs_coords'] = obs_coords
#     159
#
# ~/Desktop/climpyrical/modules/gridding.py in dist_index(lat_lon_obs, lat_lon_ens, method)
#      96     lat_ens, lon_ens = zip(*lat_lon_ens)
#      97
# ---> 98     dist_list = pairwise_distances_argmin(lat_lon_obs, lat_lon_ens, metric='cosine')
#      99     return np.asarray(dist_list)
#     100
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_argmin(X, Y, axis, metric, batch_size, metric_kwargs)
#     532     return pairwise_distances_argmin_min(X, Y, axis, metric,
#     533                                          metric_kwargs=metric_kwargs,
# --> 534                                          batch_size=batch_size)[0]
#     535
#     536
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_argmin_min(X, Y, axis, metric, batch_size, metric_kwargs)
#     448     indices, values = zip(*pairwise_distances_chunked(
#     449         X, Y, reduce_func=_argmin_min_reduce, metric=metric,
# --> 450         **metric_kwargs))
#     451     indices = np.concatenate(indices)
#     452     values = np.concatenate(values)
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1446             X_chunk = X[sl]
#    1447         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
# -> 1448                                      n_jobs=n_jobs, **kwds)
#    1449         if ((X is Y or Y is None)
#    1450                 and PAIRWISE_DISTANCE_FUNCTIONS.get(metric, None)
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1586         func = partial(distance.cdist, metric=metric, **kwds)
#    1587
# -> 1588     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1589
#    1590
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1204
#    1205     if effective_n_jobs(n_jobs) == 1:
# -> 1206         return func(X, Y, **kwds)
#    1207
#    1208     # enforce a threading backend to prevent data communication overhead
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in cosine_distances(X, Y)
#     679     """
#     680     # 1.0 - cosine_similarity(X, Y) without copy
# --> 681     S = cosine_similarity(X, Y)
#     682     S *= -1
#     683     S += 1
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1034
#    1035     K = safe_sparse_dot(X_normalized, Y_normalized.T,
# -> 1036                         dense_output=dense_output)
#    1037
#    1038     return K
#
# ~/climpyrical-venv/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     140         return ret
#     141     else:
# --> 142         return np.dot(a, b)
#     143
#     144
#
# MemoryError:

# %% [markdown]
# #### Create the pseudo observations and regress

# %%
obs_idx = generate_pseudo_obs(iens, 0.0003)
print("Taking", obs_idx.shape[0], "pseudo observations")

# %%
obs = iens[0, obs_idx]
eofs = vT[:4, obs_idx]

print("Check that the pseudo observations and the EOFs contain the same number of grids:",
      '\nEOF shape: ', eofs.shape, '\n'
      'Matched Obs shape: ', obs.shape)

# %% [markdown]
# Fit the EOFs tot he pseudo observations and predict their values

# %%
model = fit_eof(eofs.T, obs.flatten())
predictions = predict_dv(model, eofs.T)

# %%
sns.jointplot(obs.T, predictions.T, kind='reg', color='blue',  marker='+',scatter_kws={"s": 0.01})
sns.scatterplot(obs.T, predictions.T, marker='+')
sns.lineplot(obs.T, obs.T, color='r', dashes=True)
plt.xlabel('Observations')
plt.ylabel('Reconstruction')

slope, intercept, r_value, p_value, std_err = linregress(obs.T, predictions.T)
print("slope", slope, "r2_val", r_value)

# %% [markdown]
# #### Use the real observations and regress

# %%
robs_idx = ndf['matched_idx']
robs = (ndf['quantile'].values)/10.0 # fix units
reofs = vT[:4, robs_idx]

# %% [markdown]
# Compare the distributions of the station observations and of the models

# %%
plt.figure(figsize=(10, 6))
plt.title('KDE Distribution of {} Values'.format(dv))
sns.distplot(robs, label='station')
sns.distplot(iens[0, robs_idx], label='RCM field')
plt.legend()

# %% [markdown]
# Fit the model and predict it

# %%
rmodel = fit_eof(reofs.T, robs.flatten())
linrpredictions = predict_dv(rmodel, reofs.T)
# Out:
# Regressed model score: 0.4196706899455199 0.4196706899455199

# %%
sns.jointplot(robs, linrpredictions, kind='reg', color='blue', marker='+',scatter_kws={"s": 0.01})
sns.scatterplot(robs, linrpredictions, 
                color="blue",
                marker='+',
                alpha=0.3)

sns.lineplot(robs.T, 
          robs.T,
          color='r',
            dashes=True)

plt.xlabel('Observations')
plt.ylabel('Reconstruction')

slope, intercept, r_value, p_value, std_err = linregress(robs, linrpredictions)
print("slope", slope, "r2_val", r_value)

print("Std deviation ratio of vectors:", np.mean(np.std(iens, axis=1))/np.std(robs))
# Out:
# slope 0.41967068994551937 r2_val 0.6478199517964228
# Std deviation ratio of vectors: 1.8763562785874366
